# %%
import csv
import sqlite3
import pandas as pd

# %%
df = pd.read_csv('mushrooms.csv')
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
n_df = df.copy()
n_df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
n_df['class'].replace('e', 0, inplace=True)
n_df['class'].replace('p', 1, inplace=True)
n_df['class'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
n_df['cap-shape'].replace('b', 0, inplace=True)
n_df['cap-shape'].replace('c', 1, inplace=True)
n_df['cap-shape'].replace('x', 2, inplace=True)
n_df['cap-shape'].replace('f', 3, inplace=True)
n_df['cap-shape'].replace('k', 4, inplace=True)
n_df['cap-shape'].replace('s', 5, inplace=True)
n_df['cap-shape'].unique()
# Out:
# array([2, 0, 5, 3, 4, 1], dtype=int64)

# %%
n_df['cap-surface'].replace('f', 0, inplace=True)
n_df['cap-surface'].replace('g', 1, inplace=True)
n_df['cap-surface'].replace('y', 2, inplace=True)
n_df['cap-surface'].replace('s', 3, inplace=True)
n_df['cap-surface'].unique()
# Out:
# array([3, 2, 0, 1], dtype=int64)

# %%
n_df['cap-color'].replace('n', 0, inplace=True)
n_df['cap-color'].replace('b', 1, inplace=True)
n_df['cap-color'].replace('c', 2, inplace=True)
n_df['cap-color'].replace('g', 3, inplace=True)
n_df['cap-color'].replace('r', 4, inplace=True)
n_df['cap-color'].replace('p', 5, inplace=True)
n_df['cap-color'].replace('u', 6, inplace=True)
n_df['cap-color'].replace('e', 7, inplace=True)
n_df['cap-color'].replace('w', 8, inplace=True)
n_df['cap-color'].replace('y', 9, inplace=True)
n_df['cap-color'].unique()
# Out:
# array([0, 9, 8, 3, 7, 5, 1, 6, 2, 4], dtype=int64)

# %%
n_df['bruises'].replace('f', 0, inplace=True)
n_df['bruises'].replace('t', 1, inplace=True)
n_df['bruises'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
n_df['odor'].replace('a', 0, inplace=True)
n_df['odor'].replace('l', 1, inplace=True)
n_df['odor'].replace('c', 2, inplace=True)
n_df['odor'].replace('y', 3, inplace=True)
n_df['odor'].replace('f', 4, inplace=True)
n_df['odor'].replace('m', 5, inplace=True)
n_df['odor'].replace('n', 6, inplace=True)
n_df['odor'].replace('p', 7, inplace=True)
n_df['odor'].replace('s', 8, inplace=True)
n_df['odor'].unique()
# Out:
# array([7, 0, 1, 6, 4, 2, 3, 8, 5], dtype=int64)

# %%
n_df['gill-attachment'].replace('a', 0, inplace=True)
n_df['gill-attachment'].replace('d', 1, inplace=True)
n_df['gill-attachment'].replace('f', 2, inplace=True)
n_df['gill-attachment'].replace('n', 3, inplace=True)
n_df['gill-attachment'].unique()
# Out:
# array([2, 0], dtype=int64)

# %%
n_df['gill-spacing'].replace('c', 0, inplace=True)
n_df['gill-spacing'].replace('w', 1, inplace=True)
n_df['gill-spacing'].replace('d', 2, inplace=True)
n_df['gill-spacing'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
n_df['gill-size'].replace('b', 0, inplace=True)
n_df['gill-size'].replace('n', 1, inplace=True)
n_df['gill-size'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
n_df['gill-color'].replace('k', 0, inplace=True)
n_df['gill-color'].replace('n', 1, inplace=True)
n_df['gill-color'].replace('b', 2, inplace=True)
n_df['gill-color'].replace('h', 3, inplace=True)
n_df['gill-color'].replace('g', 4, inplace=True)
n_df['gill-color'].replace('r', 5, inplace=True)
n_df['gill-color'].replace('o', 6, inplace=True)
n_df['gill-color'].replace('p', 7, inplace=True)
n_df['gill-color'].replace('u', 8, inplace=True)
n_df['gill-color'].replace('e', 9, inplace=True)
n_df['gill-color'].replace('w', 10, inplace=True)
n_df['gill-color'].replace('y', 11, inplace=True)
n_df['gill-color'].unique()
# Out:
# array([ 0,  1,  4,  7, 10,  3,  8,  9,  2,  5, 11,  6], dtype=int64)

# %%
n_df['stalk-shape'].replace('t', 0, inplace=True)
n_df['stalk-shape'].replace('e', 1, inplace=True)
n_df['stalk-shape'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
n_df['stalk-root'].replace('e', 0, inplace=True)
n_df['stalk-root'].replace('c', 1, inplace=True)
n_df['stalk-root'].replace('b', 2, inplace=True)
n_df['stalk-root'].replace('r', 3, inplace=True)
n_df['stalk-root'].replace('?', 4, inplace=True)
n_df['stalk-root'].unique()
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
n_df['stalk-surface-above-ring'].replace('f', 0, inplace=True)
n_df['stalk-surface-above-ring'].replace('y', 1, inplace=True)
n_df['stalk-surface-above-ring'].replace('k', 2, inplace=True)
n_df['stalk-surface-above-ring'].replace('s', 3, inplace=True)
n_df['stalk-surface-above-ring'].unique()
# Out:
# array([3, 0, 2, 1], dtype=int64)

# %%
n_df['stalk-surface-below-ring'].replace('f', 0, inplace=True)
n_df['stalk-surface-below-ring'].replace('y', 1, inplace=True)
n_df['stalk-surface-below-ring'].replace('k', 2, inplace=True)
n_df['stalk-surface-below-ring'].replace('s', 3, inplace=True)
n_df['stalk-surface-below-ring'].unique()
# Out:
# array([3, 0, 1, 2], dtype=int64)

# %%
n_df['stalk-color-above-ring'].replace('n', 0, inplace=True)
n_df['stalk-color-above-ring'].replace('b', 1, inplace=True)
n_df['stalk-color-above-ring'].replace('c', 2, inplace=True)
n_df['stalk-color-above-ring'].replace('g', 3, inplace=True)
n_df['stalk-color-above-ring'].replace('o', 4, inplace=True)
n_df['stalk-color-above-ring'].replace('p', 5, inplace=True)
n_df['stalk-color-above-ring'].replace('e', 6, inplace=True)
n_df['stalk-color-above-ring'].replace('w', 7, inplace=True)
n_df['stalk-color-above-ring'].replace('y', 8, inplace=True)
n_df['stalk-color-above-ring'].unique()
# Out:
# array([7, 3, 5, 0, 1, 6, 4, 2, 8], dtype=int64)

# %%
n_df['stalk-color-below-ring'].replace('n', 0, inplace=True)
n_df['stalk-color-below-ring'].replace('b', 1, inplace=True)
n_df['stalk-color-below-ring'].replace('c', 2, inplace=True)
n_df['stalk-color-below-ring'].replace('g', 3, inplace=True)
n_df['stalk-color-below-ring'].replace('o', 4, inplace=True)
n_df['stalk-color-below-ring'].replace('p', 5, inplace=True)
n_df['stalk-color-below-ring'].replace('e', 6, inplace=True)
n_df['stalk-color-below-ring'].replace('w', 7, inplace=True)
n_df['stalk-color-below-ring'].replace('y', 8, inplace=True)
n_df['stalk-color-below-ring'].unique()
# Out:
# array([7, 5, 3, 1, 0, 6, 8, 4, 2], dtype=int64)

# %%
n_df['veil-type'].replace('p', 0, inplace=True)
n_df['veil-type'].replace('u', 1, inplace=True)
n_df['veil-type'].unique()
# Out:
# array([0], dtype=int64)

# %%
n_df['veil-color'].replace('n', 0, inplace=True)
n_df['veil-color'].replace('o', 1, inplace=True)
n_df['veil-color'].replace('w', 2, inplace=True)
n_df['veil-color'].replace('y', 3, inplace=True)
n_df['veil-color'].unique()
# Out:
# array([2, 0, 1, 3], dtype=int64)

# %%
n_df['ring-number'].replace('n', 0, inplace=True)
n_df['ring-number'].replace('o', 1, inplace=True)
n_df['ring-number'].replace('t', 2, inplace=True)
n_df['ring-number'].unique()
# Out:
# array([1, 2, 0], dtype=int64)

# %%
n_df['ring-type'].replace('c', 0, inplace=True)
n_df['ring-type'].replace('e', 1, inplace=True)
n_df['ring-type'].replace('f', 2, inplace=True)
n_df['ring-type'].replace('l', 3, inplace=True)
n_df['ring-type'].replace('n', 4, inplace=True)
n_df['ring-type'].replace('p', 5, inplace=True)
n_df['ring-type'].replace('s', 6, inplace=True)
n_df['ring-type'].replace('z', 7, inplace=True)
n_df['ring-type'].unique()
# Out:
# array([5, 1, 3, 2, 4], dtype=int64)

# %%
n_df['spore-print-color'].replace('k', 0, inplace=True)
n_df['spore-print-color'].replace('n', 1, inplace=True)
n_df['spore-print-color'].replace('b', 2, inplace=True)
n_df['spore-print-color'].replace('h', 3, inplace=True)
n_df['spore-print-color'].replace('r', 4, inplace=True)
n_df['spore-print-color'].replace('o', 5, inplace=True)
n_df['spore-print-color'].replace('u', 6, inplace=True)
n_df['spore-print-color'].replace('w', 7, inplace=True)
n_df['spore-print-color'].replace('y', 8, inplace=True)
n_df['spore-print-color'].unique()
# Out:
# array([0, 1, 6, 3, 7, 4, 5, 8, 2], dtype=int64)

# %%
n_df['population'].replace('a', 0, inplace=True)
n_df['population'].replace('c', 1, inplace=True)
n_df['population'].replace('n', 2, inplace=True)
n_df['population'].replace('s', 3, inplace=True)
n_df['population'].replace('v', 4, inplace=True)
n_df['population'].replace('y', 5, inplace=True)
n_df['population'].unique()
# Out:
# array([3, 2, 0, 4, 5, 1], dtype=int64)

# %%
n_df['habitat'].replace('g', 0, inplace=True)
n_df['habitat'].replace('l', 1, inplace=True)
n_df['habitat'].replace('m', 2, inplace=True)
n_df['habitat'].replace('p', 3, inplace=True)
n_df['habitat'].replace('u', 4, inplace=True)
n_df['habitat'].replace('w', 5, inplace=True)
n_df['habitat'].replace('d', 6, inplace=True)
n_df['habitat'].unique()
# Out:
# array([4, 0, 2, 6, 3, 5, 1], dtype=int64)

# %%
n_df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          2            3          0        1     7
# 1         0          2            3          9        1     0
# 2         0          0            3          8        1     1
# 3         1          2            2          8        1     7
# 4         0          2            3          3        0     6
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          4            3          0        0     6
# 8120      0          2            3          0        0     6
# 8121      0          3            3          0        0     6
# 8122      1          4            2          0        0     3
# 8123      0          2            3          0        0     6
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   2             0          1           0  ...
# 1                   2             0          0           0  ...
# ...

# %%
connection = sqlite3.connect('mushroom.db')
cursor = connection.cursor()

# %%
n_df.to_sql('mushrooms', connection)
# Out:
# 8124

# %%
cursor.execute('select * from mushrooms limit 10')
for row in cursor:
    print(row)
# Out:
# (0, 1, 2, 3, 0, 1, 7, 2, 0, 1, 0, 1, 0, 3, 3, 7, 7, 0, 2, 1, 5, 0, 3, 4)
# (1, 0, 2, 3, 9, 1, 0, 2, 0, 0, 0, 1, 1, 3, 3, 7, 7, 0, 2, 1, 5, 1, 2, 0)
# (2, 0, 0, 3, 8, 1, 1, 2, 0, 0, 1, 1, 1, 3, 3, 7, 7, 0, 2, 1, 5, 1, 2, 2)
# (3, 1, 2, 2, 8, 1, 7, 2, 0, 1, 1, 1, 0, 3, 3, 7, 7, 0, 2, 1, 5, 0, 3, 4)
# (4, 0, 2, 3, 3, 0, 6, 2, 1, 0, 0, 0, 0, 3, 3, 7, 7, 0, 2, 1, 1, 1, 0, 0)
# (5, 0, 2, 2, 9, 1, 0, 2, 0, 0, 1, 1, 1, 3, 3, 7, 7, 0, 2, 1, 5, 0, 2, 0)
# (6, 0, 0, 3, 8, 1, 0, 2, 0, 0, 4, 1, 1, 3, 3, 7, 7, 0, 2, 1, 5, 0, 2, 2)
# (7, 0, 0, 2, 8, 1, 1, 2, 0, 0, 1, 1, 1, 3, 3, 7, 7, 0, 2, 1, 5, 1, 3, 2)
# (8, 1, 2, 2, 8, 1, 7, 2, 0, 1, 7, 1, 0, 3, 3, 7, 7, 0, 2, 1, 5, 0, 4, 0)
# (9, 0, 0, 3, 9, 1, 0, 2, 0, 0, 4, 1, 1, 3, 3, 7, 7, 0, 2, 1, 5, 0, 3, 2)
